# %% [markdown]
# <a href="https://colab.research.google.com/github/Karla-Valentin/Tarea-7-CyP/blob/main/Tarea_7_CyP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problema 3.1
sumpar = 0
sumimp = 0 
contpar = 0
for cont in range (0,270):
    num = int(input("Escribe un numero:"))
    residuo = num % 2
    if residuo == 0: 
        sumpar = num + sumpar 
        contpar +=1 
    else:
        sumimp = num + sumimp 
        
prom = sumpar/contpar
print("la suma de los numeros impares es:", sumimp)  
print("el promedio de los numeros pares es:", prom)    
print("-----FIN DEL PROGRAMA------")
# Out:
# Escribe un numero:1
# Escribe un numero:2
# Escribe un numero:3
# Escribe un numero:4
# Escribe un numero:5
# Escribe un numero:6
# Escribe un numero:7
# Escribe un numero:8
# Escribe un numero:9
# Escribe un numero:10
# Escribe un numero:11
# Escribe un numero:12
# Escribe un numero:13
# Escribe un numero:14
# Escribe un numero:15
# Escribe un numero:16
# Escribe un numero:17
# Escribe un numero:18
# Escribe un numero:19
# Escribe un numero:20
# Escribe un numero:21
# Escribe un numero:22
# Escribe un numero:23
# Escribe un numero:24
# Escribe un numero:25
# Escribe un numero:26
# Escribe un numero:27
# Escribe un numero:28
# Escribe un numero:29
# Escribe un numero:30
# Escribe un numero:31
# Escribe un numero:32
# Escribe un numero:33
# Escribe un numero:34
# Escribe un numero:35
# Escribe un numero:36
# Escribe un numero:37
# Escribe un numero:38
# Escribe un numero:39
# Escribe un numero:40
# Escribe un numero:41
# Escribe un numero:42
# Escribe un numero:43
# ...

# %%
#Problema 3.2

BAND ='T' 
SUMSER = 0
i = 2
print("Todos los términos de la serie son:")
while i <= 1800:
    SUMSER =+1
    print(i)
    if BAND == 'T':
        BAND = 'F'
        i=i+3
    else:
        BAND = 'T' 
        i=i+2        
print("-----FIN DEL PROGRAMA------")
# Out:
# Todos los términos de la serie son:
# 2
# 5
# 7
# 10
# 12
# 15
# 17
# 20
# 22
# 25
# 27
# 30
# 32
# 35
# 37
# 40
# 42
# 45
# 47
# 50
# 52
# 55
# 57
# 60
# 62
# 65
# 67
# 70
# 72
# 75
# 77
# 80
# 82
# 85
# 87
# 90
# 92
# 95
# 97
# 100
# 102
# 105
# 107
# 110
# 112
# 115
# 117
# 120
# 122
# 125
# 127
# 130
# 132
# 135
# 137
# 140
# 142
# 145
# 147
# 150
# 152
# 155
# 157
# 160
# 162
# 165
# 167
# 170
# 172
# 175
# 177
# 180
# 182
# 185
# 187
# 190
# 192
# 195
# 197
# 200
# 202
# 205
# 207
# 210
# 212
# 215
# 217
# 220
# 222
# 225
# 227
# 230
# 232
# 235
# 237
# 240
# 242
# 245
# 247
# 250
# 252
# 255
# 257
# 260
# 262
# 265
# 267
# 270
# 272
# 275
# 277
# 280
# 282
# 285
# 287
# 290
# 292
# 295
# 297
# 300
# 302
# 305
# 307
# 310
# 312
# 315
# 317
# 320
# 322
# 325
# 327
# 330
# 332
# 335
# 337
# 340
# 342
# 345
# 347
# 350
# 352
# 355
# 357
# 360
# 362
# 365
# 367
# 370
# 372
# 375
# 377
# 380
# 382
# 385
# 387
# 390
# 392
# 395
# 397
# 400
# 402
# 405
# 407
# 410
# 412
# 415
# 417
# ...

# %%
#Problema 3.3

SERIE = 0
N = int(input("Ingresa un numero entero positivo:"))
BAND = 'T' 
i = 1
for i in range (1, N+1):
    if BAND == 'T':
        SERIE +=(1/i)
        BAND = 'F'
    else: 
        SERIE -=(1/i)
        BAND = 'T'
i +=1  
print(SERIE)      
print("-----FIN DEL PROGRAMA------")
# Out:
# Ingresa un numero entero positivo:8
# 0.6345238095238095
# -----FIN DEL PROGRAMA------

# %%
#Probelma 3.4
NOM = 0 
sueldo = [855,760.32,1100.2,614,2600,817.5,1280.3,687,-1] 
i = 0
while sueldo[i] > -1:
    if sueldo[i] < 1000:
        NSUE = round(sueldo[i]*1.15,2)
    else: 
        NSUE =round(sueldo[i]*1.12,2) 
    NOM= round(NOM+NSUE,2)
    i +=1
    print("Tu nuevo sueldo es:", NSUE)    
print("La nomina total es:",NOM)  
print("-----FIN DEL PROGRAMA------")
# Out:
# Tu nuevo sueldo es: 983.25
# Tu nuevo sueldo es: 874.37
# Tu nuevo sueldo es: 1232.22
# Tu nuevo sueldo es: 706.1
# Tu nuevo sueldo es: 2912.0
# Tu nuevo sueldo es: 940.12
# Tu nuevo sueldo es: 1433.94
# Tu nuevo sueldo es: 790.05
# La nomina total es: 9872.05
# -----FIN DEL PROGRAMA------
